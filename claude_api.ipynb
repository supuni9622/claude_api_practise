# %% [markdown]
# <a href="https://colab.research.google.com/github/supuni9622/claude_api_practise/blob/main/claude_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install dependencies
# %pip install anthropic python-dotenv

# %%
from anthropic.types import message
#Making a request using claude SDK
from google.colab import userdata
from anthropic import Anthropic

client = Anthropic(api_key=userdata.get('ANTHROPIC_API_KEY'))
model="claude-sonnet-5"

message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role":"user",
            "content":"What is quantum computing? explain in one sentence"
        }
    ]
)
print(f"message: {message}")

# %% [markdown]
# # New Section
